# %% [markdown]
# # Introduction
#
# This workout comes from [2023 Week 16 | Power BI: Measure Format Strings and Conditionally Formatted Titles](https://workout-wednesday.com/pbi-2023-w16/), the main focus of which is a dashboard allowing the user to choose the number of top products to be included in the report and the metric to be used in the report visuals.

# %%
import pandas as pd

# %%
file_path = '../data/Dataset-Customer Profitability.xlsx'
data = pd.read_excel(file_path, sheet_name=None)
data.keys()
# Out:
# dict_keys(['state', 'executive', 'industry', 'customer', 'product', 'scenario', 'date', 'bu', 'factsales'])

# %%
top_num = 5
metrics = {
    'product': '# of Customers', 
}

data_customer = data['factsales'].merge(
    data['product'], on='Product Key', how='left')
data_customer.groupby('Product', dropna=False).nunique().sort_values(by='Customer Key', ascending=False)
# Out:
#          YearPeriod  Customer Key  Product Key  BU Key  Scenario Key  Revenue  \
# Product
# Primus           16            32            1       4             2     6025
# MI-72             6            17            1       2             2      410
# NaN              16            16            1      13             2     1721
# Gladius          16            14            1       2             2     2244
# Sova             16            10            1       4             2      209
# Doroga            8             7            1       1             2      319
# Gunner            8             3            1       4             2        7
#
#          Material Costs  Labor Costs Variable  Taxes  Rev for Exp Travel  \
# Product
# Primus                1                   536      1                2690
# MI-72                 1                   214      1                  23
# NaN                   1                   733      3                 187
# ...

# %%
data_customer.groupby('Product', dropna=False).sum().sort_values(by='Revenue', ascending=False)
# Out:
#          YearPeriod  Customer Key  Product Key   BU Key  Scenario Key  \
# Product
# Primus   5548753490     275880400       551020  1229829         40261
# Gladius  1981735161      98614531       393600   144987         14374
# NaN      1324598312      66122252       328850   440259          9634
# Sova      179443603       8963366         8910    43398          1305
# Doroga    208984054      10386706        31140    50862          1501
# MI-72     192546452        968681        76480   148996          1403
# Gunner    159715983        826325        65026    81778          1156
#
#               Revenue  Material Costs  Labor Costs Variable  Taxes  \
# Product
# Primus   1.208542e+08            0.00            7334396.19      0
# Gladius  5.909644e+07            0.00           10554049.96      0
# NaN      3.861561e+07            0.00            7232198.47  31680
# Sova     8.511302e+06        83950.94            3013747.20  64630
# ...

# %%
data_customer['COGS'] = data_customer.iloc[:,range(6, 12)].sum(axis=1)
data_customer.groupby('Product', dropna=False).sum().sort_values(by='COGS', ascending=False)
# Out:
#          YearPeriod  Customer Key  Product Key   BU Key  Scenario Key  \
# Product
# Primus   5548753490     275880400       551020  1229829         40261
# Gladius  1981735161      98614531       393600   144987         14374
# NaN      1324598312      66122252       328850   440259          9634
# Doroga    208984054      10386706        31140    50862          1501
# Sova      179443603       8963366         8910    43398          1305
# MI-72     192546452        968681        76480   148996          1403
# Gunner    159715983        826325        65026    81778          1156
#
#               Revenue  Material Costs  Labor Costs Variable  Taxes  \
# Product
# Primus   1.208542e+08            0.00            7334396.19      0
# Gladius  5.909644e+07            0.00           10554049.96      0
# NaN      3.861561e+07            0.00            7232198.47  31680
# Doroga   7.362616e+06            0.00             208723.28      0
# ...

# %%
data_revenue['Gross Margin'] = data_revenue['Revenue'] - data_revenue['COGS']
data_revenue.sort_values(by='Gross Margin', ascending=False)
# Out:
#      YearPeriod  Customer Key   BU Key  Scenario Key       Revenue  \
# 1.0  5548753490     275880400  1229829         40261  1.208542e+08
# 3.0  1981735161      98614531   144987         14374  5.909644e+07
# NaN  1324598312      66122252   440259          9634  3.861561e+07
# 0.0   179443603       8963366    43398          1305  8.511302e+06
# 2.0   208984054      10386706    50862          1501  7.362616e+06
# 4.0   192546452        968681   148996          1403  6.905502e+05
# 5.0   159715983        826325    81778          1156  7.830000e+04
#
#      Material Costs  Labor Costs Variable  Taxes  Rev for Exp Travel  \
# 1.0            0.00            7334396.19      0          8526994.77
# 3.0            0.00           10554049.96      0          5066073.52
# NaN            0.00            7232198.47  31680          3370629.98
# 0.0        83950.94            3013747.20  64630           263674.94
# 2.0            0.00             208723.28      0           444634.87
# ...

# %%
data_revenue['Gross Margin %'] = data_revenue['Gross Margin'] / data_revenue['Revenue']
data_revenue.sort_values(by='Gross Margin %', ascending=False)
# Out:
#      YearPeriod  Customer Key   BU Key  Scenario Key       Revenue  \
# 5.0   159715983        826325    81778          1156  7.830000e+04
# 0.0   179443603       8963366    43398          1305  8.511302e+06
# NaN  1324598312      66122252   440259          9634  3.861561e+07
# 1.0  5548753490     275880400  1229829         40261  1.208542e+08
# 3.0  1981735161      98614531   144987         14374  5.909644e+07
# 2.0   208984054      10386706    50862          1501  7.362616e+06
# 4.0   192546452        968681   148996          1403  6.905502e+05
#
#      Material Costs  Labor Costs Variable  Taxes  Rev for Exp Travel  \
# 5.0            0.00                  0.00      0                0.00
# 0.0        83950.94            3013747.20  64630           263674.94
# NaN            0.00            7232198.47  31680          3370629.98
# 1.0            0.00            7334396.19      0          8526994.77
# 3.0            0.00           10554049.96      0          5066073.52
# ...
